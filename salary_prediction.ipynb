# %%
#general
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings as w
w('ignore')
import seaborn as sns

#misc
from datetime import datetime,date
from dateutil.relativedelta import relativedelta

#Models
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,r2_score


#Productionizing the ML model:
import pickle
#to display all rows of a dataframe in jupyter
pd.options.display.max_rows
pd.set_option('display.max_rows',None)

# %% [markdown]
# # Data Scraping from glassdoor
# Selenium was used to scrape all the desired data from Glassdoor

# %%
import glassdoor_scraper as gs
dataset = gs.get_jobs('data scientist', 1000, False, '/chromedriver', 10)
data = dataset.drop(dataset.columns[0], axis=1)

# %% [markdown]
# # Data Cleaning

# %%
#remove the rows where there is '-1'
data = data[data['Salary Estimate'] != '-1']

#two columns created denoting if 'per hour' and 'employer provided salary' exists in respective rows
data['hourly'] = data['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
data['employerprovided'] = data['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary' in x.lower() else 0)


#'per hour' and 'employed provided salary' is removed along with '$' and 'K'
data['Salary Estimate'] = data['Salary Estimate'].apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:','').replace('$','').replace('k',''))


#the salary range is separated from the bracketed text - (glassdoor est)
data['Salary Estimate'] = data['Salary Estimate'].apply(lambda x: x.split('(')[0])


#hyphen is removed and left side and right side of the salary are separated in min and max salary
data['min_salary'] = data['Salary Estimate'].apply(lambda x: x.split('-')[0]).apply(lambda x: int(x))
data['max_salary'] = data['Salary Estimate'].apply(lambda x: x.split('-')[1]).apply(lambda x: int(x))



#average salary
data['avg_salary'] = data[['min_salary','max_salary']].mean(axis=1)


#'Company Name': Now, let's retain only company text in "company name" field
data['company_name_text'] = data.apply(lambda x: x['Company Name'] if x['Rating'] < 1 else x['Company Name'][0:-4], axis=1)


#'Location':  Only the state name is retained in the location column
data['state'] = data['Location'].apply(lambda x: x.split(',')[1])
#to view how many companies are there in each state
#data['state'].value_counts() #a good way to check for outliers


#Founded: Will calculate and store the age of the Company 
data['company_age'] = data['Founded'].apply(lambda x: datetime.now().year - x if x!=-1 else x)



#Headquarters and state: will find out if the location of the job is the headquarters
data['same_location'] = data.apply(lambda x: 1 if x['state'] in x['Headquarters'] else 0 , axis=1)



#Job Description: If certain important data science tools exist, insert 1
#tools: python, SQL, R, excel, sas, hadoop
data['python'] = data['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
data['sql'] = data['Job Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0)
data['tableau'] = data['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)
data['excel'] = data['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
data['sas'] = data['Job Description'].apply(lambda x: 1 if 'sas' in x.lower() else 0)
data['hadoop'] = data['Job Description'].apply(lambda x: 1 if 'hadoop' in x.lower() else 0)

data['python'].value_counts()


#Checking in the job title for role names
data['job_title_simple'] = data['Job Title'].apply(lambda x: 'analyst' if 'analyst' in x.lower() else 'data scientist' if 'data scientist' in x.lower() else 'ML engineer' if 'machine learning engineer' in x.lower() else 'manager' if 'manager' in x.lower() else 'director' if 'director' in x.lower() else 'data engineer' if 'data engineer' in x.lower() else "na")

#'Job Title': Checking in the job title if positions like 'senior','junior', 'director' etc exists
data['seniority'] = data['Job Title'].apply(lambda x: 'senior' if 'sr' in x.lower() or 'senior' in x.lower() or 'sr.' in x.lower() or 'lead' in x.lower() or 'principal' in x.lower() else 'junior' if 'jr' in x.lower() or 'junior' in x.lower() or 'jr.' in x.lower() else 'na')


#'state': In the state column, los angeles in mentioned. this should be handled as LA is not a state. strip() method removes all spaces on left and right side of the string 
data['state'] = data['state'].apply(lambda x: 'CA' if x.strip().lower() == 'los angeles' else x.strip())


#'Job Description': retrieve the job description length as we can check if longer job descriptions have higher salaries
data['job_desc_len'] = data['Job Description'].apply(lambda x: len(x))


#'Competitors: we can also retrieve the no of competitors each company has:
data['competitors_num'] = data['Competitors'].apply(lambda x: len(x.split(',')) if x!= '-1' else 0) 


#change hourly salary to yearly salary. *2000 is done because there are 2000 hours in a year. /1000 is done as only first 2 digits are displayed in the column
data['min_salary'] = data.apply(lambda x: (x['min_salary']*2000)/1000 if x['hourly']==1 else x['min_salary'], axis=1)
data['max_salary'] = data.apply(lambda x: (x['max_salary']*2000)/1000 if x['hourly']==1 else x['max_salary'], axis=1)
data['avg_salary'] = data[['min_salary','max_salary']].mean(axis=1)



#'Type of Ownership': change company-public to public and company-private to private
data['Type of ownership'] = data['Type of ownership'].apply(lambda x: 'Public' if 'public' in x.lower() else 'Private' if 'private' in x.lower() else x)

# %% [markdown]
# # EDA

# %%
#Statist
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employerprovided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_name_text', 'state', 'company_age', 'same_location', 'python',
#        'sql', 'tableau', 'excel', 'sas', 'hadoop', 'job_title_simple',
#        'seniority', 'job_desc_len', 'competitors_num'],
#       dtype='object')

# %%
#correlations between important columns:
data[['company_age','Rating','job_desc_len','avg_salary']].corr()
#sns.heatmap(, annot = True)
# Out:
#               company_age    Rating  job_desc_len  avg_salary
# company_age      1.000000  0.021655      0.163911    0.021996
# Rating           0.021655  1.000000     -0.012281    0.012517
# job_desc_len     0.163911 -0.012281      1.000000    0.070474
# avg_salary       0.021996  0.012517      0.070474    1.000000

# %%
#histogram. if the variables are not normally distrubuted, it should be done for regression problems
plt.figure(figsize = [8,20])
data.hist()
#plt.tight_layout()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f945d81bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945d900f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945d93f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945d96e4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f945d99f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945d9cf978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945d9ffbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945da2fe10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f945da2fe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945da9b358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945dad15c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945dc04828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f945dc38a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945dc6bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945dca1f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945dce0208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f945de14470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945de466d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945de7d940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f945deaeba8>]],
#       dtype=object)

# %%
#bar graph for categorical columns
data_cat = data[['Location', 'Headquarters','Size',
       'Type of ownership', 'Industry', 'Sector', 'Revenue',
       'company_name_text', 'state', 'company_age', 'same_location', 'python',
       'sql', 'tableau', 'excel', 'sas', 'hadoop', 'job_title_simple',
       'seniority', 'job_desc_len', 'competitors_num']]

# %%
#cat_num = data_cat.value_counts()
for i in data_cat.columns:
    cat_num = data_cat[i].value_counts()
    print("The total no of %ss are: %d" %(i,len(cat_num)))
    graph = sns.barplot(x=cat_num.index, y = cat_num)
    graph.set_xticklabels(graph.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# The total no of Locations are: 200
# The total no of Headquarterss are: 198
# The total no of Sizes are: 9
# The total no of Type of ownerships are: 11
# The total no of Industrys are: 60
# The total no of Sectors are: 25
# The total no of Revenues are: 14
# The total no of company_name_texts are: 343
# The total no of states are: 37
# The total no of company_ages are: 102
# The total no of same_locations are: 2
# The total no of pythons are: 2
# The total no of sqls are: 2
# The total no of tableaus are: 2
# The total no of excels are: 2
# The total no of sass are: 2
# The total no of hadoops are: 2
# The total no of job_title_simples are: 7
# The total no of senioritys are: 3
# The total no of job_desc_lens are: 443
# The total no of competitors_nums are: 5

# %%
#we can check which roles have what salaries
pd.pivot_table(data, index = ['state', 'job_title_simple'], values = 'avg_salary', aggfunc = 'count').sort_values('state', ascending = False)
# Out:
#                         avg_salary
# state job_title_simple
# WI    na                         4
#       data scientist             3
#       analyst                    3
# WA    na                         1
#       data scientist            17
#       analyst                    3
# VA    na                         5
#       data scientist            18
#       data engineer             10
#       analyst                    6
#       ML engineer                2
# UT    data engineer              3
#       analyst                    4
#       data scientist             3
# TX    na                         7
#       data scientist            13
#       data engineer              8
# TN    data scientist             1
#       data engineer             10
#       analyst                    2
# SC    na                         1
# RI    analyst                    1
# PA    data scientist             6
#       data engineer              1
#       analyst                    8
#       manager                    3
#       na                        15
# OR    data scientist             3
#       data engineer              1
# OH    na                         3
#       data scientist             7
#       analyst                    4
# NY    na                        12
#       data scientist            40
#       data engineer              4
#       analyst                   14
#       ML engineer                2
# NM    data scientist             3
# NJ    data scientist             4
#       analyst                    6
#       data engineer              2
#       manager                    2
#       director                   2
#       na                         1
# NE    na                         4
# NC    na                        12
#       data scientist             3
#       data engineer              6
# MO    na                         3
#       manager                    1
#       data scientist             3
#       analyst                    2
# MN    data engineer              1
#       analyst                    1
# MI    manager                    2
#       data scientist             4
# MD    na                        16
#       data scientist            13
#       data engineer              3
#       analyst                    3
# MA    na                        46
#       manager                    5
#       director                   9
#       data scientist            30
#       data engineer              9
#       analyst                    4
# LA    analyst                    1
#       na                         1
#       data engineer              2
# KY    data scientist             2
#       na                         4
# KS    ML engineer                3
# IN    na                         4
#       data scientist             2
#       data engineer              4
# IL    na                         8
#       director                   6
#       data scientist            15
#       data engineer              7
#       analyst                    4
# ID    analyst                    2
# IA    data engineer              3
#       analyst                    2
# GA    data scientist             3
#       na                         3
# FL    data scientist             7
#       data engineer              3
#       analyst                    6
# DE    na                         6
# DC    data scientist             5
#       data engineer              4
#       analyst                    2
# CT    na                         3
#       data scientist             2
# CO    data engineer              3
#       ML engineer                1
#       analyst                    1
#       data scientist             3
#       na                         3
# CA    na                        28
#       manager                    9
#       data scientist            68
#       data engineer             25
#       analyst                   18
#       ML engineer                4
# AZ    data scientist             1
#       data engineer              5
#       analyst                    1
#       na                         2
# AL    na                         2
#       data engineer              1
#       analyst                    5

# %%
#pivoting for only data scientists
pd.pivot_table(data[data['job_title_simple']=='data scientist'], index = 'state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#        avg_salary
# state
# DC     149.000000
# CA     142.522059
# UT     140.500000
# MO     127.666667
# IL     117.233333
# NC     117.000000
# NY     115.250000
# MA     113.750000
# WI     113.500000
# PA     113.333333
# MD     109.115385
# CO     108.666667
# VA     108.416667
# NJ     106.875000
# MI     106.625000
# OH     105.285714
# TX     100.730769
# WA      99.764706
# OR      98.500000
# FL      97.357143
# TN      96.000000
# IN      84.500000
# KY      84.000000
# CT      84.000000
# GA      81.333333
# NM      74.333333
# AZ      69.500000

# %%
data_pivots = data[['Rating','Industry','Sector','Revenue','competitors_num','python','sql','sas','tableau','excel','hadoop','Type of ownership','avg_salary']]

# %%
#construct pivot tables for all the columns in the above data_pivots against 'avg_salary'
for i in data_pivots.columns:
    print(i)
    print(pd.pivot_table(data_pivots, index=i, values = 'avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# "\nfor i in data_pivots.columns:\n    print(i)\n    print(pd.pivot_table(data_pivots, index=i, values = 'avg_salary').sort_values('avg_salary', ascending=False))\n"

# %% [markdown]
# # Model Building

# %%
#selecting relevant columns:
data_model = data[['Rating','Size','Type of ownership', 'Industry', 'Sector', 'Revenue','hourly', 'employerprovided','state','same_location','company_age','python', 'sql', 'tableau', 'excel', 'sas', 'hadoop', 'job_title_simple', 'seniority', 'job_desc_len', 'competitors_num','avg_salary',]]

# %%
data_model.head(60)
# Out:
#     Rating                     Size               Type of ownership  \
# 0      3.8    501 to 1000 employees                         Private
# 1      3.4         10000+ employees              Other Organization
# 2      4.8    501 to 1000 employees                         Private
# 3      3.8   1001 to 5000 employees                      Government
# 4      2.9      51 to 200 employees                         Private
# 5      3.4     201 to 500 employees                          Public
# 6      4.1    501 to 1000 employees                         Private
# 7      3.8     201 to 500 employees                         Private
# 8      3.3         10000+ employees                        Hospital
# 9      4.6      51 to 200 employees                         Private
# 10     3.5    501 to 1000 employees                         Private
# 11     4.1  5001 to 10000 employees                          Public
# 12     3.2         10000+ employees                          Public
# 13     4.1     201 to 500 employees                         Private
# 14     3.7         10000+ employees                          Public
# 15     3.6   1001 to 5000 employees  Subsidiary or Business Segment
# 16     3.9      51 to 200 employees                          Public
# 17     4.3     201 to 500 employees                         Private
# 18     4.2      51 to 200 employees                         Private
# 19     4.0    501 to 1000 employees          Nonprofit Organization
# 20     3.2     201 to 500 employees                         Private
# 21     3.9     201 to 500 employees                         Private
# 22     3.8    501 to 1000 employees                         Private
# 23     4.3      51 to 200 employees          Nonprofit Organization
# 25     4.0    501 to 1000 employees                         Private
# 26     4.0         10000+ employees                          Public
# 27     3.5   1001 to 5000 employees                         Private
# 28     3.7  5001 to 10000 employees                          Public
# 29     4.0         10000+ employees                          Public
# 30     4.8    501 to 1000 employees                         Private
# 31     3.8   1001 to 5000 employees                      Government
# 32     3.6   1001 to 5000 employees                         Private
# 33     3.8         10000+ employees                          Public
# 34     3.8  5001 to 10000 employees                          Public
# 35     4.7     201 to 500 employees                         Private
# 36     4.2     201 to 500 employees                         Private
# 37     3.5   1001 to 5000 employees                         Private
# 38     4.7     201 to 500 employees                         Private
# 39     3.5  5001 to 10000 employees                          Public
# 40     3.5     201 to 500 employees                         Private
# 41     4.2     201 to 500 employees                         Private
# 43     3.6        1 to 50 employees                         Private
# 44     4.2      51 to 200 employees                         Private
# 45     3.4  5001 to 10000 employees                          Public
# 46     4.3   1001 to 5000 employees                          Public
# 48     5.0                  Unknown                         Private
# 49     3.7         10000+ employees                          Public
# 50     3.1  5001 to 10000 employees                         Private
# 51     4.7    501 to 1000 employees                         Private
# 52     3.7         10000+ employees                          Public
# 54     3.8    501 to 1000 employees  Subsidiary or Business Segment
# 55     3.3         10000+ employees                         Private
# 56     4.6   1001 to 5000 employees                         Private
# 57     3.7         10000+ employees                          Public
# 58     3.7         10000+ employees                          Public
# 59     3.5  5001 to 10000 employees                          Public
# 60     4.1    501 to 1000 employees                         Private
# 61     4.7      51 to 200 employees                         Private
# 62     4.1    501 to 1000 employees                         Private
# 63     3.4     201 to 500 employees                          Public
#
#                                     Industry                        Sector  \
# 0                        Aerospace & Defense           Aerospace & Defense
# 1           Health Care Services & Hospitals                   Health Care
# 2                          Security Services             Business Services
# 3                                     Energy  Oil, Gas, Energy & Utilities
# 4                    Advertising & Marketing             Business Services
# 5                                Real Estate                   Real Estate
# 6                      Banks & Credit Unions                       Finance
# 7                                 Consulting             Business Services
# 8           Health Care Services & Hospitals                   Health Care
# 9                                   Internet        Information Technology
# 10                       Other Retail Stores                        Retail
# 11                    Research & Development             Business Services
# 12       Department, Clothing, & Shoe Stores                        Retail
# 13                   Advertising & Marketing             Business Services
# 14                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 15  Motion Picture Production & Distribution                         Media
# 16                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 17   Enterprise Software & Network Solutions        Information Technology
# 18   Enterprise Software & Network Solutions        Information Technology
# 19                        Insurance Carriers                     Insurance
# 20                                  Internet        Information Technology
# 21           Insurance Agencies & Brokerages                     Insurance
# 22                  Logistics & Supply Chain    Transportation & Logistics
# 23                  Logistics & Supply Chain    Transportation & Logistics
# 25   Enterprise Software & Network Solutions        Information Technology
# 26                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 27                     Banks & Credit Unions                       Finance
# 28                        Insurance Carriers                     Insurance
# 29                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 30                         Security Services             Business Services
# 31                                    Energy  Oil, Gas, Energy & Utilities
# 32                               Real Estate                   Real Estate
# 33                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 34               Telecommunications Services            Telecommunications
# 35                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 36                               IT Services        Information Technology
# 37              Computer Hardware & Software        Information Technology
# 38                       Aerospace & Defense           Aerospace & Defense
# 39                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 40                        Insurance Carriers                     Insurance
# 41                               IT Services        Information Technology
# 43                                        -1                            -1
# 44   Enterprise Software & Network Solutions        Information Technology
# 45           Consumer Products Manufacturing                 Manufacturing
# 46                               Real Estate                   Real Estate
# 48   Enterprise Software & Network Solutions        Information Technology
# 49                               IT Services        Information Technology
# 50   Enterprise Software & Network Solutions        Information Technology
# 51                       Aerospace & Defense           Aerospace & Defense
# 52                  Industrial Manufacturing                 Manufacturing
# 54                   Advertising & Marketing             Business Services
# 55                        Insurance Carriers                     Insurance
# 56                       Aerospace & Defense           Aerospace & Defense
# 57           Insurance Agencies & Brokerages                     Insurance
# 58                       Aerospace & Defense           Aerospace & Defense
# 59                 Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 60   Enterprise Software & Network Solutions        Information Technology
# 61                               IT Services        Information Technology
# 62                     Banks & Credit Unions                       Finance
# 63                               Real Estate                   Real Estate
#
#                              Revenue  hourly  employerprovided state  \
# 0          $50 to $100 million (USD)       0                 0    NM
# 1             $2 to $5 billion (USD)       0                 0    MD
# 2         $100 to $500 million (USD)       0                 0    FL
# 3   $500 million to $1 billion (USD)       0                 0    WA
# 4           Unknown / Non-Applicable       0                 0    NY
# 5             $1 to $2 billion (USD)       0                 0    TX
# 6           Unknown / Non-Applicable       0                 0    MD
# 7           $25 to $50 million (USD)       0                 0    CA
# 8   $500 million to $1 billion (USD)       0                 0    NY
# 9         $100 to $500 million (USD)       0                 0    NY
# 10            $1 to $2 billion (USD)       0                 0    CA
# 11            $1 to $2 billion (USD)       0                 0    VA
# 12                $10+ billion (USD)       0                 0    TX
# 13          Unknown / Non-Applicable       0                 0    WA
# 14                $10+ billion (USD)       0                 0    MA
# 15          Unknown / Non-Applicable       0                 0    NJ
# 16            $1 to $5 million (USD)       0                 0    MA
# 17          Unknown / Non-Applicable       0                 0    CA
# 18          Unknown / Non-Applicable       0                 0    CA
# 19  $500 million to $1 billion (USD)       0                 0    CO
# 20          Unknown / Non-Applicable       0                 0    WA
# 21          Unknown / Non-Applicable       0                 0    TX
# 22          Unknown / Non-Applicable       0                 0    IL
# 23          $10 to $25 million (USD)       0                 0    KY
# 25        $100 to $500 million (USD)       0                 0    VA
# 26                $10+ billion (USD)       0                 0    MA
# 27        $100 to $500 million (USD)       0                 0    OR
# 28           $5 to $10 billion (USD)       0                 0    MA
# 29                $10+ billion (USD)       0                 0    CT
# 30        $100 to $500 million (USD)       0                 0    FL
# 31  $500 million to $1 billion (USD)       0                 0    WA
# 32  $500 million to $1 billion (USD)       0                 0    MI
# 33                $10+ billion (USD)       0                 0    MA
# 34            $2 to $5 billion (USD)       0                 0    CA
# 35          Unknown / Non-Applicable       0                 0    MA
# 36          Unknown / Non-Applicable       0                 0    CA
# 37            $1 to $2 billion (USD)       0                 0    CA
# 38        $100 to $500 million (USD)       0                 0    MA
# 39            $1 to $2 billion (USD)       0                 0    CA
# 40        $100 to $500 million (USD)       0                 0    NY
# 41         $50 to $100 million (USD)       0                 0    CA
# 43        Less than $1 million (USD)       0                 0    MA
# 44          Unknown / Non-Applicable       0                 0    CA
# 45            $2 to $5 billion (USD)       0                 0    NJ
# 46            $2 to $5 billion (USD)       0                 0    IL
# 48          Unknown / Non-Applicable       0                 1    DC
# 49                $10+ billion (USD)       0                 0    WA
# 50            $2 to $5 billion (USD)       0                 0    CO
# 51        $100 to $500 million (USD)       0                 0    OH
# 52                $10+ billion (USD)       0                 0    IL
# 54          Unknown / Non-Applicable       0                 0    FL
# 55                $10+ billion (USD)       0                 0    MA
# 56        $100 to $500 million (USD)       0                 0    AL
# 57                $10+ billion (USD)       0                 0    NY
# 58                $10+ billion (USD)       0                 0    CA
# 59            $1 to $2 billion (USD)       0                 0    NM
# 60          Unknown / Non-Applicable       0                 0    CA
# 61          Unknown / Non-Applicable       0                 0    MO
# 62          Unknown / Non-Applicable       0                 0    MD
# 63            $1 to $2 billion (USD)       0                 0    TX
#
#     same_location  ...  sql  tableau  excel  sas  hadoop  job_title_simple  \
# 0               0  ...    0        1      1    1       0    data scientist
# 1               1  ...    0        0      0    0       0    data scientist
# 2               1  ...    1        0      1    1       0    data scientist
# 3               1  ...    0        0      0    0       0    data scientist
# 4               1  ...    1        0      1    1       0    data scientist
# 5               1  ...    1        0      1    0       0    data scientist
# 6               1  ...    0        0      1    0       0    data scientist
# 7               0  ...    1        0      1    0       0    data scientist
# 8               1  ...    0        0      0    0       0                na
# 9               1  ...    0        0      0    0       0    data scientist
# 10              1  ...    0        0      0    0       0    data scientist
# 11              1  ...    1        0      0    0       1    data scientist
# 12              0  ...    1        0      0    0       1    data scientist
# 13              1  ...    1        1      1    0       0           analyst
# 14              0  ...    1        0      0    0       0    data scientist
# 15              1  ...    0        0      1    0       0     data engineer
# 16              1  ...    0        0      1    0       0                na
# 17              1  ...    0        0      1    0       1    data scientist
# 18              1  ...    1        0      0    0       0    data scientist
# 19              1  ...    1        0      1    0       0    data scientist
# 20              1  ...    1        0      0    0       0    data scientist
# 21              0  ...    0        0      1    0       0    data scientist
# 22              0  ...    1        0      1    0       0    data scientist
# 23              0  ...    1        1      1    0       0    data scientist
# 25              1  ...    0        0      0    0       0    data scientist
# 26              0  ...    0        0      1    0       0    data scientist
# 27              0  ...    1        1      1    0       0    data scientist
# 28              1  ...    0        0      1    0       0           analyst
# 29              0  ...    0        0      1    0       0    data scientist
# 30              1  ...    1        0      1    1       0    data scientist
# 31              1  ...    0        0      0    0       0    data scientist
# 32              1  ...    1        0      0    1       0    data scientist
# 33              0  ...    0        0      0    0       0    data scientist
# 34              1  ...    1        0      1    0       0    data scientist
# 35              1  ...    0        0      1    0       0    data scientist
# 36              0  ...    1        1      1    0       0           analyst
# 37              1  ...    0        1      0    0       1    data scientist
# 38              1  ...    1        0      1    0       1    data scientist
# 39              0  ...    0        0      1    0       0    data scientist
# 40              1  ...    1        0      1    0       0     data engineer
# 41              1  ...    1        1      1    0       0           analyst
# 43              1  ...    1        0      1    0       0     data engineer
# 44              1  ...    0        0      0    0       0    data scientist
# 45              0  ...    0        0      0    0       0                na
# 46              1  ...    1        1      1    0       1    data scientist
# 48              0  ...    0        0      1    0       0    data scientist
# 49              0  ...    1        1      1    1       0    data scientist
# 50              0  ...    0        0      1    0       0           analyst
# 51              0  ...    0        0      0    0       0                na
# 52              1  ...    0        1      0    0       0    data scientist
# 54              1  ...    1        1      1    0       1    data scientist
# 55              1  ...    0        0      0    0       0    data scientist
# 56              1  ...    0        1      1    0       0           analyst
# 57              0  ...    1        0      1    0       0    data scientist
# 58              0  ...    1        1      1    0       0    data scientist
# 59              0  ...    0        0      1    0       0    data scientist
# 60              1  ...    0        0      1    0       0    data scientist
# 61              1  ...    1        0      0    0       0    data scientist
# 62              1  ...    0        0      1    0       0    data scientist
# 63              1  ...    1        0      1    0       0    data scientist
#
#     seniority job_desc_len competitors_num  avg_salary
# 0          na         2536               0        72.0
# 1          na         4783               0        87.5
# 2          na         3461               0        85.0
# 3          na         3883               3        76.5
# 4          na         2728               3       114.5
# 5          na         3747               3        95.0
# 6          na         1786               0        73.5
# 7          na         3804               0       114.0
# 8          na         1538               0        61.0
# 9          na         4574               2       140.0
# 10         na         2757               0       163.5
# 11         na         3490               0        85.0
# 12         na         3934               3       139.0
# 13         na         4897               0        65.5
# 14         na         3731               3       113.5
# 15         na         1889               0       146.0
# 16         na         3639               3       102.0
# 17         na         4163               0       153.5
# 18         na         3512               0       142.5
# 19         na         4397               0        87.5
# 20         na         2918               3       105.5
# 21     senior         6909               0        96.0
# 22         na         6408               0       112.5
# 23         na         2907               0        84.0
# 25         na         3760               3       143.0
# 26         na         3698               0        86.5
# 27         na         4420               0        99.5
# 28         na         4900               0        47.5
# 29         na         5015               0        84.0
# 30         na         3461               0        85.0
# 31         na         3883               3        76.5
# 32         na         3342               0        96.0
# 33         na         5045               0       114.5
# 34         na         2327               0       121.0
# 35         na         2161               3       112.5
# 36         na         1739               0       106.0
# 37         na         5000               1       107.0
# 38         na         3703               0       110.0
# 39     senior         3555               0       147.5
# 40         na         1739               0       106.0
# 41         na         3053               3        88.0
# 43         na         1996               0        98.5
# 44         na         3833               0       142.5
# 45         na         3550               3        82.5
# 46     senior         9120               3       130.0
# 48         na         3213               0       155.0
# 49     senior         7286               3       184.5
# 50         na         3412               0        29.5
# 51         na         2682               3        86.5
# 52         na         2739               3        81.0
# 54         na         2915               0        91.0
# 55         na         4244               3       114.5
# 56         na         1629               0        68.0
# 57         na         4734               3       115.0
# 58         na         4448               0       109.5
# 59         na         3543               0        75.5
# 60         na         4203               3       154.5
# 61         na         5020               2       143.5
# 62         na         1786               0        73.5
# 63         na         3747               3        95.0
#
# [60 rows x 22 columns]

# %%
#creating dummies for categorical variables
data_dummies = pd.get_dummies(data_model)
data_dummies[['Rating','avg_salary']].head(20)
# Out:
#     Rating  avg_salary
# 0      3.8        72.0
# 1      3.4        87.5
# 2      4.8        85.0
# 3      3.8        76.5
# 4      2.9       114.5
# 5      3.4        95.0
# 6      4.1        73.5
# 7      3.8       114.0
# 8      3.3        61.0
# 9      4.6       140.0
# 10     3.5       163.5
# 11     4.1        85.0
# 12     3.2       139.0
# 13     4.1        65.5
# 14     3.7       113.5
# 15     3.6       146.0
# 16     3.9       102.0
# 17     4.3       153.5
# 18     4.2       142.5
# 19     4.0        87.5

# %%
#splitting dependant and dependant variables and then creating train and test set
x = data_dummies.drop('avg_salary', axis=1)
y = data_dummies['avg_salary'].values.reshape(-1,1)
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
#model1: Multi linear regression
#using statsmodels:
x_sm = sm.add_constant(x) 
model1 = sm.OLS(y,x_sm)
model1.fit().summary()

#using sklearn
lm = LinearRegression()
lm.fit(xtrain,ytrain)
print("LM normal: ",np.mean(cross_val_score(lm, xtrain,ytrain, scoring= 'neg_mean_absolute_error', cv=3)))


#using lasso regression 
lasso = Lasso(alpha =0.04) #alpha=1 is default
lasso.fit(xtrain,ytrain)
print("lasso: ",np.mean(cross_val_score(lasso, xtrain,ytrain, scoring= 'neg_mean_absolute_error', cv=3)))
#let's try different alpha values by using a for loop

alpha=[]
error = []
for i in np.arange(0.01,1,0.01):
    alpha.append(i)
    lm_lasso = Lasso(alpha=i)
    error.append(np.mean(cross_val_score(lm_lasso, xtrain,ytrain, scoring= 'neg_mean_absolute_error', cv=3)))
    
                            
plt.plot(alpha,error)
plt.xlabel("alpha values")
plt.ylabel("error values")

#the peak of the graph would be the the optimum alpha value. to retrieve, put the lists in a df and find max(error)
tup = tuple(zip(error,alpha))
df_err = pd.DataFrame(tup, columns = ['error','alpha'])
opt_alpha =  df_err[df_err['error']==max(df_err['error'])]
print("the error and alpha value for best lasso: ",opt_alpha)
# Out:
# LM normal:  -20.07470195553596
# lasso:  -19.217339133979884
# the error and alpha value for best lasso:         error  alpha
# 3 -19.217339   0.04

# %%
#Random Forest
rf = RandomForestRegressor(criterion =  'mse', max_features =  'auto', n_estimators =  300)
print("For default rf, the error is:", np.mean(cross_val_score(rf,xtrain,ytrain,scoring = 'neg_mean_absolute_error',cv = 3)))
print("For default rf, the r2_score is:", np.mean(cross_val_score(rf,xtrain,ytrain,cv = 3)))
rf.fit(xtrain,ytrain)
# Out:
# For default rf, the error is: -13.986537227890866
# For default rf, the r2_score is: 0.6867855239934105
# r2 for RF is:  0.6472226019310339
# adj r2 for RF is:  2.6842275778776448

# %%
#Hyperparameter Tuning using GridSearch
rf_gs = RandomForestRegressor()
params = {'criterion' : ['mse','mae'], 'n_estimators':[100,300,400,500], 'max_features':['auto','sqrt','log2']} 
grid_model = GridSearchCV(rf_gs, cv=3, param_grid = params, scoring = 'neg_mean_absolute_error')
grid_model.fit(xtrain,ytrain)
print("error after grid search: ", grid_model.best_score_)
print("The parameters given by the grid searchh is:", grid_model.best_params_)
# Out:
# '\nrf_gs = RandomForestRegressor()\nparams = {\'criterion\' : [\'mse\',\'mae\'], \'n_estimators\':[100,300,400,500], \'max_features\':[\'auto\',\'sqrt\',\'log2\']} \ngrid_model = GridSearchCV(rf_gs, cv=3, param_grid = params, scoring = \'neg_mean_absolute_error\')\ngrid_model.fit(xtrain,ytrain)\nprint("error after grid search: ", grid_model.best_score_)\nprint("The parameters given by the grid searchh is:", grid_model.best_params_)\n'

# %%
#predicting on the test sets.
print("mae for LM is: ", mean_absolute_error(ytest, lm.predict(xtest)))
print("mae for Lasso is: ", mean_absolute_error(ytest, lasso.predict(xtest)))
print("mae for RF is: ", mean_absolute_error(ytest, grid_model.best_estimator_.predict(xtest)))
print("r2 for RF is: ", r2_score(ytest, grid_model.best_estimator_.predict(xtest)))


'''
mae for LM is:  19.09621634412441
mae for Lasso is:  18.87340281254084
mae for RF is:  12.691744966442952 #grid model
'''
# Out:
# '\nprint("mae for LM is: ", mean_absolute_error(ytest, lm.predict(xtest)))\nprint("mae for Lasso is: ", mean_absolute_error(ytest, lasso.predict(xtest)))\nprint("mae for RF is: ", mean_absolute_error(ytest, grid_model.best_estimator_.predict(xtest)))\nprint("r2 for RF is: ", r2_score(ytest, grid_model.best_estimator_.predict(xtest)))\nprint("adj r2 for RF is: ", adjusted_r2(ytest, grid_model.best_estimator_.predict(xtest), xtest))\n\n\nmae for LM is:  19.09621634412441\nmae for Lasso is:  18.87340281254084\nmae for RF is:  12.691744966442952 #grid model\n'

# %% [markdown]
# # Productionization

# %% [markdown]
# productionization: create a flask api endpoint, where job information is sent and the API returns the salary

# %%
import pickle
#create a pickle file from the model. the below lines store it in the same directory as the code file
pickl = {'model': grid_model.best_estimator_}
pickle.dump(pickl, open('model_file' + ".p","wb"))
# Out:
# '\n#create a pickle file from the model. the below lines store it in the same directory as the code file\npickl = {\'model\': grid_model.best_estimator_}\npickle.dump(pickl, open(\'model_file\' + ".p","wb"))\n'

# %%
#loading the model from the pickle
file_name = "models/model_file.p"
with open(file_name, 'rb') as pickled:
    data = pickle.load(pickled)
    model = data['model'] #pickled model is saved in model now
    
model.predict(xtest.iloc[0,:].values.reshape(1,-1))
# Out:
# '\nfile_name = "models/model_file.p"\nwith open(file_name, \'rb\') as pickled:\n    data = pickle.load(pickled)\n    model = data[\'model\'] #pickled model is saved in model now\n    \nmodel.predict(xtest.iloc[0,:].values.reshape(1,-1)) #we check here if the model was loaded correctly.\n'
